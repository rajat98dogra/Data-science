# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd
import math
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
SIZE=20
np.random.seed(10)
df= pd.DataFrame(columns=['price','rooms','age','area'])
df.area= np.array(np.random.randint(4000,5000,size=(SIZE)))
df.rooms= np.array(np.random.randint(2,5,size=(SIZE)))
df.age= np.array(np.random.randint(5,25,size=(SIZE)))
price= []
# df.shape
for i in range(SIZE):
    price.append(math.floor(df.rooms.iloc[i]*4000 + df.area.iloc[i]%10*1000 + df.age.iloc[i]*0.6 ))

# %%
df.price=np.array(price)
df
# Out:
#     price  rooms  age  area
# 0   13010      2   17  4265
# 1   13003      2    6  4125
# 2   22005      4    9  4996
# 3   15013      2   23  4527
# 4   16010      4   18  4320
# 5   25009      4   16  4369
# 6   15009      3   15  4123
# 7   14008      2   14  4156
# 8   13012      2   20  4985
# 9   19013      4   23  4733
# 10  18012      3   21  4496
# 11  21007      4   12  4925
# 12  13009      3   16  4881
# 13  20013      3   22  4008
# 14  15011      3   19  4073
# 15  18007      3   12  4256
# 16  16009      4   16  4490
# 17  12003      3    6  4040
# 18  10003      2    5  4502
# 19  16010      4   17  4420

# %%
plt.figure(figsize=(12,5))
sns.barplot(df.price,df.area)
# Out:
# <AxesSubplot:xlabel='price', ylabel='area'>

# %%
X=df.iloc[:,1:]
y=df.iloc[:,0]
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 3.61230954e+03,  1.10755801e+02, -5.92949253e-01])

# %%
lr.intercept_
# Out:
# 6679.822078778461

# %%
ypred=lr.predict(x_test)
ypred
# Out:
# array([12123.06029804, 15785.7705256 , 17206.02861019, 20238.81091059,
#        20870.01484752])

# %%
residual = np.array(y_test - ypred)
residual
# Out:
# array([  879.93970196, -3782.7705256 , -2195.02861019, -4229.81091059,
#        -1857.01484752])
