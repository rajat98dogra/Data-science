# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import seaborn as sns

# %%
M=50
S=12
X = np.random.normal(M,S,200)

# %%
plt.hist(X)
# Out:
# (array([ 5.,  7., 25., 44., 46., 38., 20., 10.,  4.,  1.]),
#  array([18.13290327, 25.40595649, 32.67900972, 39.95206294, 47.22511616,
#         54.49816939, 61.77122261, 69.04427583, 76.31732906, 83.59038228,
#         90.8634355 ]),
#  <BarContainer object of 10 artists>)

# %%
def find_mu(x,mu,sigma):
    return (1/np.sqrt(2*np.pi*(sigma**2)))*(np.exp( - ((x -mu)**2 / (2*sigma**2)) ))
def find_sigma(x,mu,sigma):
    return (1/np.sqrt(2*np.pi*(sigma**2)))*(np.exp( - ((x -mu)**2 / (2*sigma**2)) ))

# %%
m=[]
for x in X:
    res=float('-inf')
    lik = []
    for mu in range(0,100,10):
        l = find_mu(x,mu,S)
        lik.append(l)
    res = lik.index(max(lik))*10
    m.append(res)
plt.hist(m)
# Out:
# (array([ 5., 12., 46.,  0., 64., 46.,  0., 20.,  6.,  1.]),
#  array([20., 27., 34., 41., 48., 55., 62., 69., 76., 83., 90.]),
#  <BarContainer object of 10 artists>)

# %%
si=0
mu = np.sum(X)/len(X)
for i in X:
    si += (i-M)**2
s = np.sqrt(si/len(X))
print(mu,s,)
# Out:
# 50.68146254465295 12.443157575420049
